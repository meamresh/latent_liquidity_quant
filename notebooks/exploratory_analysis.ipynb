# %%
import os
import sys
import numpy as np
from IPython.display import Image

# 1. FIX PATH (Must be BEFORE imports)
sys.path.insert(0, os.path.abspath('..')) 

# 2. IMPORTS
from experiments.animate_crisis import create_vanguard_animation
from experiments.visualize_crisis import create_vanguard_plots

# %%
# 3. RUN STATIC (Very stable)
create_vanguard_plots(start_date='2007-06-01', end_date='2009-03-31', is_notebook=True)
# Out:
# Generating Vanguard-grade static analysis: 2007-06-01 to 2009-03-31...

# %%
# 4. RUN ANIMATION (Unstable, may fail due to ffmpeg issues)
create_vanguard_animation(start_date='2007-06-01', end_date='2009-03-31', is_notebook=True)
# Out:
# INFO:models.finance_state_space:Initialized FinanceStateSpaceModel with state_dim=3, obs_dim=6
# Initializing Vanguard-grade systemic risk animation: 2007-06-01 to 2009-03-31...
# Propagating particles to 2007-06-01...
# Filtering 439 frames for animation...
